# %%
#IMPORTAMOS LAS VARIABLES 
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sklearn.datasets import load_iris
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.preprocessing import StandardScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## CARGAMOS EL DATASET

# %%
iris = load_iris(as_frame=True)

# %%
print(iris.DESCR)

# %%
# Convertimos los datos en DataFrame
dfIris = iris.frame
dfIris.head(2)

# %%
dfIris.tail(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dfIris.tail(2)
#
# NameError: name 'dfIris' is not defined

# %%
iris.target_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 iris.target_names
#
# NameError: name 'iris' is not defined

# %%
#Cambiamos la columna de Target por Especie
dfIris.rename(columns={"target" : "species"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Cambiamos la columna de Target por Especie
# ----> 2 dfIris.rename(columns={"target" : "species"}, inplace=True)
#
# NameError: name 'dfIris' is not defined

# %%
#Remplazamos los valores numericos por las especies
dfIris["species"] = dfIris["species"].map(
    {
        0: "setosa",
        1: "versicolor",
        2: "virginica"
    }
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Remplazamos los valores numericos por las especies
# ----> 2 dfIris["species"] = dfIris["species"].map(
#       3     {
#       4         0: "setosa",
#       5         1: "versicolor",
#       6         2: "virginica"
#       7     }
#       8 )
#
# NameError: name 'dfIris' is not defined

# %% [markdown]
# ## Variables predictoras y Variable objetivo
#
# X (Variables predictoras) son aquellas que me permiten hacer la prediccion
# y (objetivo) Lo que quiero predecir

# %%
#Variables predictoras
X = dfIris.drop(columns=["species"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Variables predictoras
# ----> 2 X = dfIris.drop(columns=["species"])
#
# NameError: name 'dfIris' is not defined

# %%
# Variable objetivo
y = dfIris["species"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Variable objetivo
# ----> 2 y = dfIris["species"]
#
# NameError: name 'dfIris' is not defined

# %%
print("---Variables predictoras---")
print(X.columns)
print("---Variable Objetivo ----")
print(y.name)
# Out:
# ---Variables predictoras---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 print("---Variables predictoras---")
# ----> 2 print(X.columns)
#       3 print("---Variable Objetivo ----")
#       4 print(y.name)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## División del conjunto de datos
#
# *Training Set:* Datos para entrenamiento.
#
# *Testing Set:* Datos no vistos por el modelo, para prueba.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, #Variables predictoras
    y, #Variable objetivo,
    test_size = 0.20,
    random_state=42,
    stratify=y
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     X, #Variables predictoras
#       3     y, #Variable objetivo,
#       4     test_size = 0.20,
#       5     random_state=42,
#       6     stratify=y
#       7 )
#
# NameError: name 'train_test_split' is not defined

# %%
print("X_train: ", X_train.shape)
print("X_test: ", X_test.shape)
print("--------------------------")
print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print("X_train: ", X_train.shape)
#       2 print("X_test: ", X_test.shape)
#       3 print("--------------------------")
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # Escalado de las variables

# %%
scaler = StandardScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 scaler = StandardScaler()
#
# NameError: name 'StandardScaler' is not defined

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X_train_scaled = scaler.fit_transform(X_train)
#       2 X_test_scaled = scaler.transform(X_test)
#
# NameError: name 'scaler' is not defined

# %%
print("-----------Datos sin escalar------------")
print(X_train.head(5))
print("-----------Escalados------------")
print(X_train_scaled[:5])
# Out:
# -----------Datos sin escalar------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 print("-----------Datos sin escalar------------")
# ----> 2 print(X_train.head(5))
#       3 print("-----------Escalados------------")
#       4 print(X_train_scaled[:5])
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# # Entrenamiento del modelo

# %%
# Creamos una instancia del algoritmo
modelo = KNeighborsClassifier(
    n_neighbors = 3 #numero de vecinos a comparar
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Creamos una instancia del algoritmo
# ----> 2 modelo = KNeighborsClassifier(
#       3     n_neighbors = 3 #numero de vecinos a comparar
#       4 )
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
# Entrenamos con los datos de entrenamiento
modelo.fit(
    X_train_scaled,
    y_train
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Entrenamos con los datos de entrenamiento
# ----> 2 modelo.fit(
#       3     X_train_scaled,
#       4     y_train
#       5 )
#
# NameError: name 'modelo' is not defined

# %% [markdown]
# # Prediccion con los datos de prueba

# %%
prediccion = modelo.predict(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 prediccion = modelo.predict(X_test_scaled)
#
# NameError: name 'modelo' is not defined

# %%
pd.DataFrame({
    "Especie real" : y_test.values,
    "Especie predicha" : prediccion
}).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.DataFrame({
#       2     "Especie real" : y_test.values,
#       3     "Especie predicha" : prediccion
#       4 }).head(10)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Evaluacion del modelo
#
# *Las metricas a usar son: accuracy, precision, recall, f1-score

# %%
#Accuracy
accuracy = accuracy_score(y_test, prediccion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 #Accuracy
# ----> 2 accuracy = accuracy_score(y_test, prediccion)
#
# NameError: name 'accuracy_score' is not defined

# %%
print ( f"Accuracy / Exactitud del modelo es:  { accuracy: .4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print ( f"Accuracy / Exactitud del modelo es:  { accuracy: .4f}")
#
# NameError: name 'accuracy' is not defined

# %%
#Matriz de confusión
matrizConfusion = confusion_matrix(y_test, prediccion)
matrizConfusion_df = pd.DataFrame(
    matrizConfusion,
    index = modelo.classes_,
    columns = modelo.classes_
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 #Matriz de confusión
# ----> 2 matrizConfusion = confusion_matrix(y_test, prediccion)
#       3 matrizConfusion_df = pd.DataFrame(
#       4     matrizConfusion,
#       5     index = modelo.classes_,
#       6     columns = modelo.classes_
#       7 )
#
# NameError: name 'confusion_matrix' is not defined

# %%
matrizConfusion_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 matrizConfusion_df
#
# NameError: name 'matrizConfusion_df' is not defined

# %%
# Matriz de metricas : Clasification Report
print (classification_report(y_test, prediccion))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Matriz de metricas : Clasification Report
# ----> 2 print (classification_report(y_test, prediccion))
#
# NameError: name 'classification_report' is not defined

# %%
## Variables de importancia

# %%
 ## importancia = modelo.feature_importances_ (Knn no tiene featu
corr = dfIris.corr(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1  ## importancia = modelo.feature_importances_ (Knn no tiene featu
# ----> 2 corr = dfIris.corr(numeric_only=True)
#
# NameError: name 'dfIris' is not defined

# %%
import seaborn as sns
sns.heatmap ( corr, annot=True, cmap="Blues")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 import seaborn as sns
# ----> 2 sns.heatmap ( corr, annot=True, cmap="Blues")
#
# NameError: name 'corr' is not defined

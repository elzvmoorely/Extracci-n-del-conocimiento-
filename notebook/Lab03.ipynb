# %% [markdown]
# # Fecha: 24 de mayo de 2026
# # Autor: Elizabeth Vega Pacheco
# # Laboratorio 3: Simulación de Datos de Instagram
#
# ## Objetivo
#
# Generar datos sintéticos relacionados con influencers y publicaciones en redes sociales para su análisis.

# %%
import pandas as pd
import random

# %%
# Datos base para el dataset de Instagram 
datosInstagram = {
    "influencer": ["nomada_digital", "foodie_viajero", "mexico_en_lente", "carma_travels", "chef_playero"],
    "likes": [15400, 8900, 32100, 4200, 11300],
    "comentarios": [720, 410, 1580, 190, 540],
    "fecha": ["2025-11-04", "2026-01-15", "2026-02-28", "2026-04-10", "2026-05-25"],
    "tipo_post": ["carrusel", "reel", "foto", "story", "reel"]
}

# %%
dfDatos = pd.DataFrame(datosInstagram)

cantidad = 1000000

# Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "influencer": [random.choice(dfDatos["influencer"]) for _ in range(cantidad)],
    "likes": [random.randint(100, 500000) for _ in range(cantidad)],
    "comentarios": [random.randint(10, 50000) for _ in range(cantidad)],
    "fecha": [random.choice(dfDatos["fecha"]) for _ in range(cantidad)],
    "tipo_post": [random.choice(dfDatos["tipo_post"]) for _ in range(cantidad)]
})

# %%
# Mostrar forma del DataFrame
dfMillon.shape
# Out:
# (1000000, 5)

# %%
# Mostramos los primeros 5
dfMillon.head()
# Out:
#         influencer   likes  comentarios       fecha tipo_post
# 0  mexico_en_lente  275277        23966  2026-04-10      reel
# 1  mexico_en_lente  429955         6651  2025-11-04      reel
# 2   nomada_digital  218390        30893  2026-05-25  carrusel
# 3  mexico_en_lente  491205        28727  2025-11-04      foto
# 4  mexico_en_lente  436650        26704  2026-05-25      reel

# %% [markdown]
# ## Interpretación de Resultados
#
# Los datos generados representan distintos tipos de publicaciones e interacciones dentro de una red social.
#
# ## Conclusiones
#
# La simulación de datos permite realizar análisis y pruebas sin utilizar información real.

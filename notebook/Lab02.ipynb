# %% [markdown]
# # Titulo: Laboratorio  2
# # Fecha: 22 de mayo
# # Autor: Elizabth Vega Pacheco
# # Generación de Big Data
#
# ## Objetivo
# Generar un conjunto masivo de datos sintéticos para analizar el comportamiento de grandes volúmenes de información.

# %%
#Importamos la libreria pandas
import pandas as pd
import random

# %%
#Conjunto de datos base para la generación del Big Data
datos = {
    "usuario": ["ana","pepe", "luis","rosita","carolina","paco"],
    "edad":[14,22,35,40,62,70],
    "cuidad":["cuitlahuac","yanga","atoyac","paraje","fortin","cuichapa"],
    "compras_realizadas":[5,10,1,2,15,3],
    "activo": ["True","True","True","False","True","False"],
    "fecha_registro":["2026-01-10","2026-05-21","2026-02-10","2026-03-11","2026-04-15","2026-07-25"]
}

# %%
#Creamos el dataframe
dfDatos = pd.DataFrame(datos)

# %%
#Mostramos dato
dfDatos
# Out:
#     usuario  edad      cuidad  compras_realizadas activo fecha_registro
# 0       ana    14  cuitlahuac                   5   True     2026-01-10
# 1      pepe    22       yanga                  10   True     2026-05-21
# 2      luis    35      atoyac                   1   True     2026-02-10
# 3    rosita    40      paraje                   2  False     2026-03-11
# 4  carolina    62      fortin                  15   True     2026-04-15
# 5      paco    70    cuichapa                   3  False     2026-07-25

# %%
#Cantidad de registros a generar aleatoriamente 
cantidad=1000000

# %%
#Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "nombre": [random.choice(dfDatos["usuario"]) for _ in range(cantidad)],
    "edad": [random.randint(18,80) for _ in range(cantidad)],
    "cuidad": [random.choice(dfDatos["cuidad"]) for _ in range(cantidad)],
    "compras_realizadas": [random.randint(1,10) for _ in range(cantidad)],
    "activo": [random.choice(dfDatos["activo"]) for _ in range(cantidad)],
    "fecha_registro": [random.choice(dfDatos["fecha_registro"]) for _ in range(cantidad)]
})

# %%
#Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "nombre": [random.choice(dfDatos["usuario"]) for _ in range(cantidad)],
    "edad": [random.randint(18,80) for _ in range(cantidad)],
    "ciudad": [random.choice(dfDatos["ciudad"]) for _ in range(cantidad)],
    "compras_realizadas": [random.randint(1,10) for _ in range(cantidad)],
    "activo": [random.choice(dfDatos["activo"]) for _ in range(cantidad)],
    "fecha_registro": [random.choice(dfDatos["fecha_registro"]) for _ in range(cantidad)]
})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ciudad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       1 #Crear el dataFrame de 1000000 de registros
#       2 dfMillon = pd.DataFrame({
#       3     "nombre": [random.choice(dfDatos["usuario"]) for _ in range(cantidad)],
#       4     "edad": [random.randint(18,80) for _ in range(cantidad)],
# ----> 5     "ciudad": [random.choice(dfDatos["ciudad"]) for _ in range(cantidad)],
#       6     "compras_realizadas": [random.randint(1,10) for _ in range(cantidad)],
#       7     "activo": [random.choice(dfDatos["activo"]) for _ in range(cantidad)],
#       8     "fecha_registro": [random.choice(dfDatos["fecha_registro"]) for _ in range(cantidad)]
#       9 })
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'ciudad'

# %%
print(dfDatos.columns.tolist())

# %%
cantidad = 1000000

#Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "nombre": [random.choice(dfDatos["usuario"]) for _ in range(cantidad)],
    "edad": [random.randint(18,80) for _ in range(cantidad)],
    "cuidad": [random.choice(dfDatos["cuidad"]) for _ in range(cantidad)],
    "compras_realizadas": [random.randint(1,10) for _ in range(cantidad)],
    "activo": [random.choice(dfDatos["activo"]) for _ in range(cantidad)],
    "fecha_registro": [random.choice(dfDatos["fecha_registro"]) for _ in range(cantidad)]
})

# %%
dfMillon.shape

# %%
dfMillon.dtypes

# %%
dfMillon.memory_usage(deep=True)

# %%
dfMillon.memory_usage(deep=True).sum()/1024**2

# %% [markdown]
# ## Interpretación de Resultados
#
# La generación de datos sintéticos permite simular escenarios reales de análisis sin utilizar información sensible.
#
# ## Conclusiones
#
# Python facilita la creación de grandes volúmenes de datos para pruebas y experimentación.

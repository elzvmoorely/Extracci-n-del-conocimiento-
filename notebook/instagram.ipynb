# %%
#Titulo: instagram
#Fecha: 22 de mayo
#Autor: Elizabeth Vega
import pandas as pd
import random

# %%
# Datos base para el dataset de Instagram
datosInstagram = {
    "influencer": ["cancun_vibes", "playa_lover", "turismo_cancun", "lifestyle_mx", "cancun_travel"],
    "likes": [1000, 5000, 3000, 8000, 2000],
    "comentarios": [50, 200, 150, 400, 100],
    "fecha": ["2022-01-01", "2022-06-15", "2023-03-10", "2023-08-20", "2024-01-05"],
    "tipo_post": ["foto", "reel", "carrusel", "story", "foto"]
}

# %%
dfDatos = pd.DataFrame(datosInstagram)

cantidad = 1000000

# Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "influencer": [random.choice(dfDatos["influencer"]) for _ in range(cantidad)],
    "likes": [random.randint(100, 500000) for _ in range(cantidad)],
    "comentarios": [random.randint(10, 50000) for _ in range(cantidad)],
    "fecha": [random.choice(dfDatos["fecha"]) for _ in range(cantidad)],
    "tipo_post": [random.choice(dfDatos["tipo_post"]) for _ in range(cantidad)]
})

# %%
# Mostrar forma del DataFrame
dfMillon.shape
# Out:
# (1000000, 5)

# %%
# Mostrar primeras filas
dfMillon.head()
# Out:
#        influencer   likes  comentarios       fecha tipo_post
# 0    cancun_vibes  320154        21131  2022-01-01      foto
# 1    cancun_vibes  232887        29731  2022-06-15     story
# 2  turismo_cancun  150839        39556  2022-06-15     story
# 3    lifestyle_mx  324061        45556  2022-06-15     story
# 4   cancun_travel  129111        37037  2024-01-05      foto
